# %% [markdown]
# # Production Credentials
#
# **Admin User**
# - Email: `admin@yardflow.com`
# - Password: `YardFlow2026!`
#
# **Demo User**
# - Email: `demo@yardflow.com`
# - Password: `demo123`

# %%
// Proposed railway.json change
{
  "$schema": "https://railway.app/railway.schema.json",
  "build": {
    "builder": "NIXPACKS",
    "nixpacksConfigPath": "eventops/nixpacks.toml",
    // Removed 'npm ci' to rely on Nixpacks caching
    "buildCommand": "cd eventops && npx prisma generate && NODE_OPTIONS=\"--max-old-space-size=4096\" npm run build"
  },
  "deploy": {
    "startCommand": "cd eventops && ./start-production.sh",
    "restartPolicyType": "ON_FAILURE",
    "restartPolicyMaxRetries": 5
  }
}
